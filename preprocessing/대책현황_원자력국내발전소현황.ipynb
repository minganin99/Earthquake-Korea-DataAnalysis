# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/mkmy7/OneDrive/바탕 화면/Earthquake_DA/Earthquake-Korea-DataAnalysis/dataset/최종데이터셋/대책현황/원자력발전소/국내원자력발전소현황.csv', encoding='euc-kr')
df
# Out:
#     번호    구분 발전소명  호기    노형       원자로공급사  용량1(MWe)  용량2(MWe)       건설허가일  \
# 0    1  정지원전   고리  #1   PWR          W/H       587       587  1972-05-31
# 1    2  정지원전   월성  #1  PHWR  AECL(CANDU)       679       679  1978-02-15
# 2    1  운영원전   고리  #2   PWR          W/H       650      4550  1978-11-18
# 3    2  운영원전   고리  #3   PWR          W/H       950      4550  1979-12-24
# 4    3  운영원전   고리  #4   PWR          W/H       950      4550  1979-12-24
# 5    4  운영원전  신고리  #1   PWR  두중(OPR1000)      1000      4550  2005-07-01
# 6    5  운영원전  신고리  #2   PWR  두중(OPR1000)      1000      4550  2005-07-01
# 7    6  운영원전   새울  #1   PWR  두중(APR1400)      1400      2800  2008-04-15
# 8    7  운영원전   새울  #2   PWR  두중(APR1400)      1400      2800  2008-04-15
# 9    8  운영원전   월성  #2   PWR  AECL(CANDU)       700      4100  1992-08-28
# 10   9  운영원전   월성  #3   PWR  AECL(CANDU)       700      4100  1994-02-26
# 11  10  운영원전   월성  #4   PWR  AECL(CANDU)       700      4100  1994-02-26
# ...

# %%
df = df.drop('번호', axis=1)
df = df.drop('건설허가일', axis=1)
df = df.drop('착공일(기초굴착일)', axis=1)
df = df.drop('운영허가일', axis=1)
df
# Out:
#       구분 발전소명  호기    노형       원자로공급사  용량1(MWe)  용량2(MWe)     상업운전개시일  \
# 0   정지원전   고리  #1   PWR          W/H       587       587  1978-04-29
# 1   정지원전   월성  #1  PHWR  AECL(CANDU)       679       679  1983-04-22
# 2   운영원전   고리  #2   PWR          W/H       650      4550  1983-07-25
# 3   운영원전   고리  #3   PWR          W/H       950      4550  1985-09-30
# 4   운영원전   고리  #4   PWR          W/H       950      4550  1986-04-29
# 5   운영원전  신고리  #1   PWR  두중(OPR1000)      1000      4550  2011-02-28
# 6   운영원전  신고리  #2   PWR  두중(OPR1000)      1000      4550  2012-07-20
# 7   운영원전   새울  #1   PWR  두중(APR1400)      1400      2800  2016-12-20
# 8   운영원전   새울  #2   PWR  두중(APR1400)      1400      2800  2019-08-29
# 9   운영원전   월성  #2   PWR  AECL(CANDU)       700      4100  1997-07-01
# 10  운영원전   월성  #3   PWR  AECL(CANDU)       700      4100  1998-07-01
# 11  운영원전   월성  #4   PWR  AECL(CANDU)       700      4100  1999-10-01
# 12  운영원전  신월성  #1   PWR  두중(OPR1000)      1000      4100  2012-07-31
# ...

# %%
df.to_csv('국내원자력발전소현황_EDA.csv', index=False, encoding='utf-8')
