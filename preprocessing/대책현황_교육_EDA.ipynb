# %%
import pandas as pd

# %%
df_edu = pd.read_excel('C:/Users/mkmy7/OneDrive/바탕 화면/Earthquake_DA/Earthquake-Korea-DataAnalysis/dataset/최종데이터셋/대책현황/교육/국내자연재해_국내인식현황.csv')
df_edu
# Out:
#     행정구역별(1)  특성별(1)       특성별(2) 2008 2008.1  2008.2 2008.3       2008.4  \
# 0   행정구역별(1)  특성별(1)       특성별(2)    계  매우 안전  비교적 안전     보통  비교적 안전하지 않음
# 1         전국      전체            계  100    0.7    16.5   42.7         35.1
# 2        NaN      성별           남자  100      1    18.3   43.1           33
# 3        NaN     NaN           여자  100    0.5    14.8   42.3         37.1
# 4        NaN      연령       15∼19세  100    2.1    19.7     44         29.8
# ..       ...     ...          ...  ...    ...     ...    ...          ...
# 59       NaN     NaN    60세 이상*고졸  100    0.9    17.3   38.5         37.7
# 60       NaN     NaN  60세 이상*대졸이상  100    0.7    17.8   47.5         29.9
# 61       NaN     NaN  65세 이상*중졸이하  100    0.7    13.8   40.3           40
# 62       NaN     NaN    65세 이상*고졸  100    0.7    17.6     38         37.9
# 63       NaN     NaN  65세 이상*대졸이상  100    1.2    18.4   46.9         29.6
#
#         2008.5 2010  ...  2020.2 2020.3       2020.4      2020.5 2022 2022.1  \
# ...

# %%
df_edu = df_edu.drop('행정구역별(1)', axis=1)
df_edu = df_edu.drop('특성별(1)', axis=1)
df_edu
# Out:
#          특성별(2) 2008 2008.1  2008.2 2008.3       2008.4      2008.5 2010  \
# 0        특성별(2)    계  매우 안전  비교적 안전     보통  비교적 안전하지 않음  매우 안전하지 않음    계
# 1             계  100    0.7    16.5   42.7         35.1         4.9  100
# 2            남자  100      1    18.3   43.1           33         4.6  100
# 3            여자  100    0.5    14.8   42.3         37.1         5.2  100
# 4        15∼19세  100    2.1    19.7     44         29.8         4.4  100
# ..          ...  ...    ...     ...    ...          ...         ...  ...
# 59    60세 이상*고졸  100    0.9    17.3   38.5         37.7         5.7  100
# 60  60세 이상*대졸이상  100    0.7    17.8   47.5         29.9         4.1  100
# 61  65세 이상*중졸이하  100    0.7    13.8   40.3           40         5.2  100
# 62    65세 이상*고졸  100    0.7    17.6     38         37.9         5.8  100
# 63  65세 이상*대졸이상  100    1.2    18.4   46.9         29.6         3.9  100
#
#    2010.1  2010.2  ...  2020.2 2020.3       2020.4      2020.5 2022 2022.1  \
# ...

# %%
df_edu.rename(columns={'특성별(2)': '특성'}, inplace=True)
df_edu
# Out:
#              특성 2008 2008.1  2008.2 2008.3       2008.4      2008.5 2010  \
# 0        특성별(2)    계  매우 안전  비교적 안전     보통  비교적 안전하지 않음  매우 안전하지 않음    계
# 1             계  100    0.7    16.5   42.7         35.1         4.9  100
# 2            남자  100      1    18.3   43.1           33         4.6  100
# 3            여자  100    0.5    14.8   42.3         37.1         5.2  100
# 4        15∼19세  100    2.1    19.7     44         29.8         4.4  100
# ..          ...  ...    ...     ...    ...          ...         ...  ...
# 59    60세 이상*고졸  100    0.9    17.3   38.5         37.7         5.7  100
# 60  60세 이상*대졸이상  100    0.7    17.8   47.5         29.9         4.1  100
# 61  65세 이상*중졸이하  100    0.7    13.8   40.3           40         5.2  100
# 62    65세 이상*고졸  100    0.7    17.6     38         37.9         5.8  100
# 63  65세 이상*대졸이상  100    1.2    18.4   46.9         29.6         3.9  100
#
#    2010.1  2010.2  ...  2020.2 2020.3       2020.4      2020.5 2022 2022.1  \
# ...

# %%
df_edu.to_csv('교육.csv', index=False, encoding='utf-8')
