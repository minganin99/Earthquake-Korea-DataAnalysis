# %%
import pandas as pd

# %%
df1 = pd.read_excel('C:/Users/mkmy7/OneDrive/바탕 화면/Earthquake_DA/Earthquake-Korea-DataAnalysis/dataset/최종데이터셋/대책현황/내진설계/국내공공건축물_내진설계현황.xlsx')
df1
# Out:
#       지역  전체 공공건축물(동수)  전체 공공건축물(연면적)  내진설계 대상(동수)  내진설계 대상(연면적)  내진설계 적용(동수)  \
# 0   총 합계        170641   2.426909e+08        57856  2.284054e+08        18823
# 1     서울         11364   3.356134e+07         5954  3.284602e+07         2083
# 2     부산          7750   1.632259e+07         3068  1.583060e+07          943
# 3     대구          3777   1.189830e+07         1945  1.164489e+07          712
# 4     인천          5728   1.069201e+07         2266  1.023375e+07          780
# 5     광주          2544   6.417313e+06         1185  6.245197e+06          478
# 6     대전          2954   9.010625e+06         1482  8.817213e+06          511
# 7     울산          3387   4.877625e+06         1147  4.639943e+06          399
# 8     세종           848   1.634185e+06          336  1.557345e+06          163
# 9     경기         22075   4.721931e+07         9153  4.542438e+07         3672
# 10    강원         17602   1.744624e+07         4727  1.588821e+07         1566
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   지역             18 non-null     object
#  1   전체 공공건축물(동수)   18 non-null     int64
#  2   전체 공공건축물(연면적)  18 non-null     float64
#  3   내진설계 대상(동수)    18 non-null     int64
#  4   내진설계 대상(연면적)   18 non-null     float64
#  5   내진설계 적용(동수)    18 non-null     int64
#  6   내진설계 적용(연면적)   18 non-null     float64
#  7   내진율(동수)        18 non-null     float64
#  8   내진율(연면적)       18 non-null     float64
# dtypes: float64(5), int64(3), object(1)
# memory usage: 1.4+ KB

# %%
df1.to_csv('국내공공건축물_내진설계현황_EDA.csv', index=False, encoding='utf-8')

# %%
df2 = pd.read_excel('C:/Users/mkmy7/OneDrive/바탕 화면/Earthquake_DA/Earthquake-Korea-DataAnalysis/dataset/최종데이터셋/대책현황/내진설계/국내주택_내진설계현황.xlsx')
df2
# Out:
#          건축물명칭       동명칭                           대지위치       허가일       착공일  \
# 0          NaN        비동            서울특별시 종로구 구기동 221번지       NaN       NaN
# 1          NaN       NaN         서울특별시 종로구 사직동 311-23번지  19930818    199308
# 2       부암스카이빌        씨동         서울특별시 종로구 부암동 129-10번지  20020713  20020722
# 3         약산빌라        다동             서울특별시 종로구 구기동 97번지  19881020       NaN
# 4          NaN       NaN            서울특별시 종로구 원서동 103번지  19960408  19960605
# ...        ...       ...                            ...       ...       ...
# 384755     NaN   제주감귤연구소  제주특별자치도 서귀포시 남원읍 하례리 1336-1번지  19960307  19960605
# 384756     NaN  대일연립주택라동    제주특별자치도 서귀포시 성산읍 고성리 1453번지       NaN       NaN
# 384757     NaN  대일연립주택다동    제주특별자치도 서귀포시 성산읍 고성리 1453번지       NaN       NaN
# 384758     NaN  대일연립주택나동    제주특별자치도 서귀포시 성산읍 고성리 1453번지       NaN       NaN
# 384759     NaN  대일연립주택가동    제주특별자치도 서귀포시 성산읍 고성리 1453번지       NaN       NaN
#
# ...

# %%
df2 = df2.drop('건축물명칭', axis=1)
df2 = df2.drop('동명칭', axis=1)
df2
# Out:
#                                  대지위치       허가일       착공일       준공일  지상층수  \
# 0                 서울특별시 종로구 구기동 221번지       NaN       NaN  19861024   3.0
# 1              서울특별시 종로구 사직동 311-23번지  19930818    199308  19931224   2.0
# 2              서울특별시 종로구 부암동 129-10번지  20020713  20020722  20030617   3.0
# 3                  서울특별시 종로구 구기동 97번지  19881020       NaN  19890215   2.0
# 4                 서울특별시 종로구 원서동 103번지  19960408  19960605  19961113   4.0
# ...                               ...       ...       ...       ...   ...
# 384755  제주특별자치도 서귀포시 남원읍 하례리 1336-1번지  19960307  19960605  19961126   3.0
# 384756    제주특별자치도 서귀포시 성산읍 고성리 1453번지       NaN       NaN  19871228   3.0
# 384757    제주특별자치도 서귀포시 성산읍 고성리 1453번지       NaN       NaN  19871228   3.0
# 384758    제주특별자치도 서귀포시 성산읍 고성리 1453번지       NaN       NaN  19871228   3.0
# 384759    제주특별자치도 서귀포시 성산읍 고성리 1453번지       NaN       NaN  19871228   3.0
#
#         지하층수   주용도  층대표용도   연면적(㎡) 내진설계\n대상여부
# ...

# %%
df_unique = df2.drop_duplicates(subset='대지위치')
df_unique
# Out:
#                                  대지위치       허가일       착공일       준공일  지상층수  \
# 0                 서울특별시 종로구 구기동 221번지       NaN       NaN  19861024   3.0
# 1              서울특별시 종로구 사직동 311-23번지  19930818    199308  19931224   2.0
# 2              서울특별시 종로구 부암동 129-10번지  20020713  20020722  20030617   3.0
# 3                  서울특별시 종로구 구기동 97번지  19881020       NaN  19890215   2.0
# 4                 서울특별시 종로구 원서동 103번지  19960408  19960605  19961113   4.0
# ...                               ...       ...       ...       ...   ...
# 384749   제주특별자치도 서귀포시 대정읍 하모리 470-1번지  19920530  19920624  19930608   4.0
# 384751   제주특별자치도 서귀포시 남원읍 하례리 349-5번지  20010618  20010723  20020207   3.0
# 384753  제주특별자치도 서귀포시 남원읍 남원리 1323-2번지  19950619  19950824  19961031   5.0
# 384755  제주특별자치도 서귀포시 남원읍 하례리 1336-1번지  19960307  19960605  19961126   3.0
# 384756    제주특별자치도 서귀포시 성산읍 고성리 1453번지       NaN       NaN  19871228   3.0
#
#         지하층수   주용도  층대표용도   연면적(㎡) 내진설계\n대상여부
# ...

# %%
df_unique.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 256792 entries, 0 to 384756
# Data columns (total 10 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   대지위치       256791 non-null  object
#  1   허가일        240756 non-null  object
#  2   착공일        189257 non-null  object
#  3   준공일        255323 non-null  object
#  4   지상층수       256788 non-null  float64
#  5   지하층수       256788 non-null  float64
#  6   주용도        256754 non-null  object
#  7   층대표용도      256788 non-null  object
#  8   연면적(㎡)     256788 non-null  float64
#  9   내진설계
# 대상여부  256788 non-null  object
# dtypes: float64(3), object(7)
# memory usage: 21.6+ MB

# %%
df_unique.to_csv('주택내진설계현황.csv', index=False, encoding='utf-8')

# %%
df_fin = pd.read_csv('주택내진설계현황.csv', encoding='euc-kr')
df_fin
# Out:
# C:\Users\mkmy7\AppData\Local\Temp\ipykernel_22376\2143873295.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_fin = pd.read_csv('주택내진설계현황.csv', encoding='euc-kr')
#                                  대지위치       허가일       착공일         준공일  지상층수  \
# 0                 서울특별시 종로구 구기동 221번지       NaN       NaN  19861024.0   3.0
# 1              서울특별시 종로구 사직동 311-23번지  19930818    199308  19931224.0   2.0
# 2              서울특별시 종로구 부암동 129-10번지  20020713  20020722  20030617.0   3.0
# 3                  서울특별시 종로구 구기동 97번지  19881020       NaN  19890215.0   2.0
# 4                 서울특별시 종로구 원서동 103번지  19960408  19960605  19961113.0   4.0
# ...                               ...       ...       ...         ...   ...
# 256787   제주특별자치도 서귀포시 대정읍 하모리 470-1번지  19920530  19920624    19930608   4.0
# 256788   제주특별자치도 서귀포시 남원읍 하례리 349-5번지  20010618  20010723    20020207   3.0
# ...

# %%
df_fin = df_fin.drop('허가일', axis=1)
df_fin = df_fin.drop('착공일', axis=1)
df_fin
# Out:
#                                  대지위치         준공일  지상층수  지하층수   주용도  층대표용도  \
# 0                 서울특별시 종로구 구기동 221번지  19861024.0   3.0   1.0  공동주택   연립주택
# 1              서울특별시 종로구 사직동 311-23번지  19931224.0   2.0   1.0  공동주택  다세대주택
# 2              서울특별시 종로구 부암동 129-10번지  20030617.0   3.0   2.0  공동주택  다세대주택
# 3                  서울특별시 종로구 구기동 97번지  19890215.0   2.0   1.0  공동주택  다세대주택
# 4                 서울특별시 종로구 원서동 103번지  19961113.0   4.0   1.0  공동주택  다세대주택
# ...                               ...         ...   ...   ...   ...    ...
# 256787   제주특별자치도 서귀포시 대정읍 하모리 470-1번지    19930608   4.0   0.0  공동주택  다세대주택
# 256788   제주특별자치도 서귀포시 남원읍 하례리 349-5번지    20020207   3.0   0.0  공동주택  다세대주택
# 256789  제주특별자치도 서귀포시 남원읍 남원리 1323-2번지    19961031   5.0   0.0  공동주택    아파트
# 256790  제주특별자치도 서귀포시 남원읍 하례리 1336-1번지    19961126   3.0   0.0  공동주택    기숙사
# 256791    제주특별자치도 서귀포시 성산읍 고성리 1453번지    19871228   3.0   0.0  공동주택   연립주택
#
#             연면적 내진설계 대상여부
# 0       1151.90         O
# ...

# %%
df_fin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 256792 entries, 0 to 256791
# Data columns (total 8 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   대지위치       256791 non-null  object
#  1   준공일        255323 non-null  object
#  2   지상층수       256788 non-null  float64
#  3   지하층수       256788 non-null  float64
#  4   주용도        256754 non-null  object
#  5   층대표용도      256788 non-null  object
#  6   연면적        256788 non-null  float64
#  7   내진설계 대상여부  256788 non-null  object
# dtypes: float64(3), object(5)
# memory usage: 15.7+ MB

# %%
df_fin.to_csv('국내주택_내진설계현황_EDA.csv', index=False, encoding='utf-8')

# %%
df = pd.read_csv('C:/Users/mkmy7/OneDrive/바탕 화면/Earthquake_DA/Earthquake-Korea-DataAnalysis/dataset/EDA후 데이터셋/대책현황/내진설계/국내주택_내진설계현황_EDA.csv')
df
# Out:
# C:\Users\mkmy7\AppData\Local\Temp\ipykernel_22376\206973002.py:1: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('C:/Users/mkmy7/OneDrive/바탕 화면/Earthquake_DA/Earthquake-Korea-DataAnalysis/dataset/EDA후 데이터셋/대책현황/내진설계/국내주택_내진설계현황_EDA.csv')
#                                  대지위치         준공일  지상층수  지하층수   주용도  층대표용도  \
# 0                 서울특별시 종로구 구기동 221번지  19861024.0   3.0   1.0  공동주택   연립주택
# 1              서울특별시 종로구 사직동 311-23번지  19931224.0   2.0   1.0  공동주택  다세대주택
# 2              서울특별시 종로구 부암동 129-10번지  20030617.0   3.0   2.0  공동주택  다세대주택
# 3                  서울특별시 종로구 구기동 97번지  19890215.0   2.0   1.0  공동주택  다세대주택
# 4                 서울특별시 종로구 원서동 103번지  19961113.0   4.0   1.0  공동주택  다세대주택
# ...                               ...         ...   ...   ...   ...    ...
# 256787   제주특별자치도 서귀포시 대정읍 하모리 470-1번지    19930608   4.0   0.0  공동주택  다세대주택
# ...
