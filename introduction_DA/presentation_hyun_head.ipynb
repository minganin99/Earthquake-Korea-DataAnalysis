# %% [markdown]
# # 발표

# %% [markdown]
# ## 서론

# %% [markdown]
# ### 전 세계에서 발생한 지진현황
# 태블로에서 확인 가능

# %% [markdown]
# ### 지진이 발생하는 이유
# 지진은 판의 충돌, 지각의 변형, 화산 활동, 지하수 침반, 태풍으로 인한 지하수 수위 상승과 같은 원인 이외에도 인간의 지반 공사, 핵실험 등 다양한 이유로 발생하고 있습니다. 지진이 위험한 이유는 대규모 지반진동 뿐만 아니라 해일 동반, 낙상사고, 여진 등으로 인류에게 막대한 피해를 끼치기 때문입니다.
#
# 비교적 최근인 2004년 푸켓의 지진해일, 2005년 카슈미르 지진, 2008년 쓰촨성 지진, 2010년 아이티 지진,2011년에 일어난 일본 지진해일은 인류에게 막대한 피해를 주었습니다. 뿐만 아니라 2011년에 일어난 일본 지진해일을 통해서 원자력 발전소의 붕괴와 같은 대참사를 통해 지진의 위험성에 대해서 체감할 수 있었습니다.
#
# 그렇다면 과연 우리가 살고 있는 대한민국은 지진의 위협으로 부터 안전할까?라는 의문이 들었고, 이러한 의문을 바탕으로 데이터 분석을 시작하였습니다.

# %% [markdown]
# ### 대한민국 국민들의 자연재해 인식 현황에 대해 알아 보겠습니다.

# %%
import pandas as pd

# 엑셀 파일 읽기
df_edu = pd.read_excel('C:/Users/campus4D036/Desktop/프로젝트/팀프로젝트/Earthquake-Korea-DataAnalysis/data_set/최종데이터셋/대책현황/교육/국내자연재해_국민인식현황1.xlsx')

# CSV 파일로 저장
df_edu.to_csv('국내자연재해_국민인식현황1.csv', index=False, encoding='utf-8-sig')

# %%
import pandas as pd
#

# 엑셀 파일 읽기
df_edu = pd.read_csv('C:/Users/campus4D036/Desktop/프로젝트/팀프로젝트/Earthquake-Korea-DataAnalysis/data_set/최종데이터셋/대책현황/교육/국내자연재해_국민인식현황1.csv')


df_edu

# %%
import pandas as pd

# CSV 파일 읽기
df_edu = pd.read_csv('C:/Users/campus4D036/Desktop/프로젝트/팀프로젝트/Earthquake-Korea-DataAnalysis/data_set/최종데이터셋/대책현황/교육/국내자연재해_국민인식현황1.csv')

# 열 이름 출력
print(df_edu.columns)

# 처음 몇 행 출력
print(df_edu.head())

# 데이터프레임 정보 출력
print(df_edu.info())

# %%
import pandas as pd

# CSV 파일 읽기

# '전체' '계' 행 추출
df_filtered = df_edu[(df_edu['특성별(1)'] == '전체') & (df_edu['특성별(2)'] == '계')]

# 데이터 확인
print(df_filtered)
print("\n열 이름:")
print(df_filtered.columns)
print("\n첫 번째 행:")
print(df_filtered.iloc[0])

# %%
import pandas as pd

# CSV 파일 읽기

# '전체' '계' 행 추출
df_filtered = df_edu[(df_edu['특성별(1)'] == '전체') & (df_edu['특성별(2)'] == '계')]

# 연도별 데이터 추출 및 재구성
years = ['2008', '2010', '2012', '2014', '2016', '2018', '2020', '2022']
result_data = []

for year in years:
    row_data = [
        df_filtered[year].values[0],
        df_filtered[f'{year}.1'].values[0],
        df_filtered[f'{year}.2'].values[0],
        df_filtered[f'{year}.3'].values[0],
        df_filtered[f'{year}.4'].values[0]
    ]
    result_data.append([year] + row_data)

# 결과 데이터프레임 생성
df_result = pd.DataFrame(result_data, columns=['연도', '매우 안전', '비교적 안전', '보통', '비교적 안전하지 않음', '매우 안전하지 않음'])
df_result = df_result.set_index('연도')

# 결과 출력
print(df_result)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
import numpy as np

# 한글 폰트 설정
font_path = "C:/Windows/Fonts/malgun.ttf"
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)

# CSV 파일 읽기

# '전체' '계' 행 추출
df_filtered = df_edu[(df_edu['특성별(1)'] == '전체') & (df_edu['특성별(2)'] == '계')]

# 연도별 데이터 추출 및 재구성
years = ['2008', '2010', '2012', '2014', '2016', '2018', '2020', '2022']
result_data = []

for year in years:
    row_data = [
        float(df_filtered[year].values[0]),
        float(df_filtered[f'{year}.1'].values[0]),
        float(df_filtered[f'{year}.2'].values[0]),
        float(df_filtered[f'{year}.3'].values[0]),
        float(df_filtered[f'{year}.4'].values[0])
    ]
    result_data.append([year] + row_data)

# 결과 데이터프레임 생성
df_result = pd.DataFrame(result_data, columns=['연도', '매우 안전', '비교적 안전', '보통', '비교적 안전하지 않음', '매우 안전하지 않음'])
df_result = df_result.set_index('연도')

# 선 그래프 생성
plt.figure(figsize=(12, 6))
plt.title('연도별 국내 자연재해 안전도 인식 변화', fontsize=16)

# 눈에 띄는 다른 색상으로 변경
colors = ['#FF1493', '#1E90FF', '#32CD32', '#FFA500', '#8B008B']
categories = ['매우 안전', '비교적 안전', '보통', '비교적 안전하지 않음', '매우 안전하지 않음']

for i, category in enumerate(categories):
    plt.plot(df_result.index, df_result[category], label=category, color=colors[i], marker='o', linewidth=2)

plt.xlabel('연도')
plt.ylabel('비율 (%)')
plt.legend(title='안전도 인식', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import font_manager, rc


# '전체' '계' 행 추출
df_filtered = df_edu[(df_edu['특성별(1)'] == '전체') & (df_edu['특성별(2)'] == '계')]

# 연도별 데이터 추출 및 재구성
years = ['2008', '2010', '2012', '2014', '2016', '2018', '2020', '2022']
result_data = []

for year in years:
    row_data = [
        float(df_filtered[year].values[0]),
        float(df_filtered[f'{year}.1'].values[0]),
        float(df_filtered[f'{year}.2'].values[0]),
        float(df_filtered[f'{year}.3'].values[0]),
        float(df_filtered[f'{year}.4'].values[0])
    ]
    result_data.append([year] + row_data)

# 결과 데이터프레임 생성
df_result = pd.DataFrame(result_data, columns=['연도', '매우 안전', '비교적 안전', '보통', '비교적 안전하지 않음', '매우 안전하지 않음'])
df_result = df_result.set_index('연도')

# 평균과 표준편차 계산
means = df_result.mean()
stds = df_result.std()

# 그래프 생성
fig, ax = plt.subplots(figsize=(12, 6))

x = np.arange(len(means))
width = 0.5

# 막대 그래프 (평균)
bars = ax.bar(x, means, width, yerr=stds, capsize=5, alpha=0.7)

# 그래프 꾸미기
ax.set_ylabel('비율 (%)')
ax.set_title('국내 자연재해 안전도 인식의 평균과 표준편차')
ax.set_xticks(x)
ax.set_xticklabels(means.index, rotation=45, ha='right')

# 범례 추가
ax.bar(0, 0, color='b', alpha=0.7, label='평균')
ax.errorbar(0, 0, yerr=1, fmt='none', color='k', capsize=5, label='표준편차')
ax.legend()

# 값 표시
for i, bar in enumerate(bars):
    height = bar.get_height()
    ax.text(bar.get_x() + bar.get_width()/2., height,
            f'{means[i]:.2f}±{stds[i]:.2f}',
            ha='center', va='bottom', rotation=0)

plt.tight_layout()
plt.show()

# %% [markdown]
# #### 매우 안전에 응답한 비율이 상승하고 있고, 최근 조사에서는 부정적 견해보다 긍적적으로 생각하는 응답이 많아졌습니다. 하지만 2014년에 발생한 세월호 사고로 인해서 갑자기 매우 안전하지 않음 수치가 상승한 모습이 보입니다.
#
# 표준 편차와 평균을 통해서 2008년 조사부터 현재까지 안전하지 않다는 견해가 높다는 것을 알 수 있습니다.

# %% [markdown]
# ### 연령대별 인식 현황입니다.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
import numpy as np


# 연령대 리스트
age_groups = ['13∼19세', '20∼29세', '30∼39세', '40∼49세', '50∼59세', '60∼69세', '70∼79세', '80세이상']

# 연도별 데이터 추출 및 재구성
years = ['2008', '2010', '2012', '2014', '2016', '2018', '2020', '2022']
result_data = []

def safe_float(x):
    try:
        return float(x)
    except ValueError:
        return np.nan

for age_group in age_groups:
    df_filtered = df_edu[(df_edu['특성별(1)'] == '연령') & (df_edu['특성별(2)'] == age_group)]
    
    for year in years:
        row_data = [
            safe_float(df_filtered[year].values[0]),
            safe_float(df_filtered[f'{year}.1'].values[0]),
            safe_float(df_filtered[f'{year}.2'].values[0]),
            safe_float(df_filtered[f'{year}.3'].values[0]),
            safe_float(df_filtered[f'{year}.4'].values[0])
        ]
        result_data.append([age_group, year] + row_data)

# 결과 데이터프레임 생성
df_result = pd.DataFrame(result_data, columns=['연령대', '연도', '매우 안전', '비교적 안전', '보통', '비교적 안전하지 않음', '매우 안전하지 않음'])

# 선 그래프 생성
fig, axs = plt.subplots(2, 3, figsize=(20, 12))
fig.suptitle('연령대별 국내 자연재해 안전도 인식 변화 (2008-2022)', fontsize=16)

colors = ['#FF1493', '#1E90FF', '#32CD32', '#FFA500', '#8B008B']
categories = ['매우 안전', '비교적 안전', '보통', '비교적 안전하지 않음', '매우 안전하지 않음']

for i, category in enumerate(categories):
    row = i // 3
    col = i % 3
    
    for age_group in age_groups:
        age_data = df_result[df_result['연령대'] == age_group]
        axs[row, col].plot(age_data['연도'], age_data[category], label=age_group, marker='o')
    
    axs[row, col].set_title(category)
    axs[row, col].set_xlabel('연도')
    axs[row, col].set_ylabel('비율 (%)')
    axs[row, col].legend(title='연령대', bbox_to_anchor=(1.05, 1), loc='upper left')
    axs[row, col].grid(True)

# 마지막 빈 서브플롯 제거
fig.delaxes(axs[1][2])

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import font_manager, rc


# 연령대 리스트
age_groups = ['13∼19세', '20∼29세', '30∼39세', '40∼49세', '50∼59세', '60∼69세', '70∼79세', '80세이상']

# 연도별 데이터 추출 및 재구성
years = ['2008', '2010', '2012', '2014', '2016', '2018', '2020', '2022']
result_data = []

def safe_float(x):
    try:
        return float(x)
    except ValueError:
        return np.nan

for age_group in age_groups:
    df_filtered = df_edu[(df_edu['특성별(1)'] == '연령') & (df_edu['특성별(2)'] == age_group)]
    
    for year in years:
        row_data = [
            safe_float(df_filtered[year].values[0]),
            safe_float(df_filtered[f'{year}.1'].values[0]),
            safe_float(df_filtered[f'{year}.2'].values[0]),
            safe_float(df_filtered[f'{year}.3'].values[0]),
            safe_float(df_filtered[f'{year}.4'].values[0])
        ]
        result_data.append([age_group, year] + row_data)

# 결과 데이터프레임 생성
df_result = pd.DataFrame(result_data, columns=['연령대', '연도', '매우 안전', '비교적 안전', '보통', '비교적 안전하지 않음', '매우 안전하지 않음'])

# 연도별로 평균과 표준편차 계산
mean_std_data = []

for year in years:
    year_data = df_result[df_result['연도'] == year][['매우 안전', '비교적 안전', '보통', '비교적 안전하지 않음', '매우 안전하지 않음']]
    means = year_data.mean()
    stds = year_data.std()
    mean_std_data.append([year] + list(means) + list(stds))

# 결과 데이터프레임 생성 (평균과 표준편차)
mean_std_columns = ['연도'] + [f'{col}_mean' for col in ['매우 안전', '비교적 안전', '보통', '비교적 안전하지 않음', '매우 안전하지 않음']] + \
                   [f'{col}_std' for col in ['매우 안전', '비교적 안전', '보통', '비교적 안전하지 않음', '매우 안전하지 않음']]
df_mean_std = pd.DataFrame(mean_std_data, columns=mean_std_columns)

# 막대 그래프 생성 (평균과 표준편차)
categories = ['매우 안전', '비교적 안전', '보통', '비교적 안전하지 않음', '매우 안전하지 않음']
fig, axs = plt.subplots(2, 3, figsize=(20, 12))
fig.suptitle('2008년부터 2022년까지 연령대별 국내 자연재해 인식의 평균과 표준편차')

for i, category in enumerate(categories):
    row = i // 3
    col = i % 3
    
    means_col = f'{category}_mean'
    stds_col = f'{category}_std'
    
    x_pos = np.arange(len(years))
    
    # 막대 그래프 그리기
    axs[row, col].bar(x_pos, df_mean_std[means_col], yerr=df_mean_std[stds_col], capsize=5, alpha=0.7, color='skyblue')
    
    # 그래프 제목 및 라벨 설정
    axs[row, col].set_title(category)
    axs[row, col].set_xticks(x_pos)
    axs[row, col].set_xticklabels(years)
    axs[row, col].set_ylabel('비율 (%)')

plt.tight_layout()
plt.show()

# %% [markdown]
# 연령대가 어릴 수록 매우 안전하다는 견해를 보이고 있었고, 연도별로 안전에 긍정적으로 반응하는 추세가 보입니다.

# %% [markdown]
# ## 교육수준 별 안전도

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
import numpy as np


# 교육 정도 리스트
education_levels = ['초졸이하', '중 졸', '고 졸', '대졸이상']

# 연도별 데이터 추출 및 재구성
years = ['2008', '2010', '2012', '2014', '2016', '2018', '2020', '2022']
result_data = []

def safe_float(x):
    try:
        return float(x)
    except ValueError:
        return np.nan

for level in education_levels:
    df_filtered = df_edu[(df_edu['특성별(1)'] == '교육정도') & (df_edu['특성별(2)'] == level)]
    
    for year in years:
        row_data = [
            safe_float(df_filtered[year].values[0]),
            safe_float(df_filtered[f'{year}.1'].values[0]),
            safe_float(df_filtered[f'{year}.2'].values[0]),
            safe_float(df_filtered[f'{year}.3'].values[0]),
            safe_float(df_filtered[f'{year}.4'].values[0])
        ]
        result_data.append([level, year] + row_data)

# 결과 데이터프레임 생성
df_result = pd.DataFrame(result_data, columns=['교육정도', '연도', '매우 안전', '비교적 안전', '보통', '비교적 안전하지 않음', '매우 안전하지 않음'])

# 선 그래프 생성
fig, axs = plt.subplots(3, 2, figsize=(20, 15))
fig.suptitle('가구원수별 국내 자연재해 안전도 인식 변화 (2020-2022)', fontsize=16)

colors = ['#FF1493', '#1E90FF', '#32CD32', '#FFA500', '#8B008B']
categories = ['매우 안전', '비교적 안전', '보통', '비교적 안전하지 않음', '매우 안전하지 않음']
linestyles = ['solid', 'dashed', 'dotted', 'dashdot']

for i, category in enumerate(categories):
    row = i // 2
    col = i % 2
    
    for j, level in enumerate(education_levels):
        level_data = df_result[df_result['교육정도'] == level]
        axs[row, col].plot(level_data['연도'], level_data[category], label=level, color=colors[j], marker='o', linestyle=linestyles[j])
    
    axs[row, col].set_title(category)
    axs[row, col].set_xlabel('연도')
    axs[row, col].set_ylabel('비율 (%)')
    axs[row, col].legend(title='교육정도', loc='best')
    axs[row, col].grid(True)

# 마지막 빈 서브플롯 제거
fig.delaxes(axs[2, 1])

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import font_manager, rc


# 교육 정도 리스트
education_levels = ['초졸이하', '중 졸', '고 졸', '대졸이상']

# 연도별 데이터 추출 및 재구성
years = ['2008', '2010', '2012', '2014', '2016', '2018', '2020', '2022']
result_data = []

def safe_float(x):
    try:
        return float(x)
    except ValueError:
        return np.nan

for level in education_levels:
    df_filtered = df_edu[(df_edu['특성별(1)'] == '교육정도') & (df_edu['특성별(2)'] == level)]
    
    for year in years:
        row_data = [
            safe_float(df_filtered[year].values[0]),
            safe_float(df_filtered[f'{year}.1'].values[0]),
            safe_float(df_filtered[f'{year}.2'].values[0]),
            safe_float(df_filtered[f'{year}.3'].values[0]),
            safe_float(df_filtered[f'{year}.4'].values[0])
        ]
        result_data.append([level, year] + row_data)

# 결과 데이터프레임 생성
df_result = pd.DataFrame(result_data, columns=['교육정도', '연도', '매우 안전', '비교적 안전', '보통', '비교적 안전하지 않음', '매우 안전하지 않음'])

# 교육 정도별로 평균과 표준편차 계산
mean_std_data = []

for level in education_levels:
    level_data = df_result[df_result['교육정도'] == level][['매우 안전', '비교적 안전', '보통', '비교적 안전하지 않음', '매우 안전하지 않음']]
    means = level_data.mean()
    stds = level_data.std()
    mean_std_data.append([level] + list(means) + list(stds))

# 결과 데이터프레임 생성 (평균과 표준편차)
mean_std_columns = ['교육정도'] + [f'{col}_mean' for col in ['매우 안전', '비교적 안전', '보통', '비교적 안전하지 않음', '매우 안전하지 않음']] + \
                   [f'{col}_std' for col in ['매우 안전', '비교적 안전', '보통', '비교적 안전하지 않음', '매우 안전하지 않음']]
df_mean_std = pd.DataFrame(mean_std_data, columns=mean_std_columns)

# 막대 그래프 생성 (평균과 표준편차)
categories = ['매우 안전', '비교적 안전', '보통', '비교적 안전하지 않음', '매우 안전하지 않음']
fig, axs = plt.subplots(3, 2, figsize=(20, 15))
fig.suptitle('2008년부터 2022년까지 교육 정도별 국내 자연재해 인식의 평균과 표준편차')

for i, category in enumerate(categories):
    row = i // 2
    col = i % 2
    
    means_col = f'{category}_mean'
    stds_col = f'{category}_std'
    
    x_pos = np.arange(len(education_levels))
    
    # 막대 그래프 그리기
    axs[row, col].bar(x_pos, df_mean_std[means_col], yerr=df_mean_std[stds_col], capsize=5, alpha=0.7, color='skyblue')
    
    # 그래프 제목 및 라벨 설정
    axs[row, col].set_title(category)
    axs[row, col].set_xticks(x_pos)
    axs[row, col].set_xticklabels(education_levels)
    axs[row, col].set_ylabel('비율 (%)')

# 마지막 빈 서브플롯 제거
fig.delaxes(axs[2, 1])

plt.tight_layout()
plt.show()

# %% [markdown]
# 상대적으로 학력이 높을수록 안전에 긍정적인 견해를 가지고 있습니다.

# %% [markdown]
# ## 성별

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
import numpy as np


# 성별 리스트
genders = ['남자', '여자']

# 연도별 데이터 추출 및 재구성
years = ['2008', '2010', '2012', '2014', '2016', '2018', '2020', '2022']
result_data = []

def safe_float(x):
    try:
        return float(x)
    except ValueError:
        return np.nan

for gender in genders:
    df_filtered = df_edu[(df_edu['특성별(1)'] == '성별') & (df_edu['특성별(2)'] == gender)]
    
    for year in years:
        row_data = [
            safe_float(df_filtered[year].values[0]),
            safe_float(df_filtered[f'{year}.1'].values[0]),
            safe_float(df_filtered[f'{year}.2'].values[0]),
            safe_float(df_filtered[f'{year}.3'].values[0]),
            safe_float(df_filtered[f'{year}.4'].values[0])
        ]
        result_data.append([gender, year] + row_data)

# 결과 데이터프레임 생성
df_result = pd.DataFrame(result_data, columns=['성별', '연도', '매우 안전', '비교적 안전', '보통', '비교적 안전하지 않음', '매우 안전하지 않음'])

# 선 그래프 생성
fig, axs = plt.subplots(3, 2, figsize=(20, 15))
fig.suptitle('성별 별 국내 자연재해 안전도 인식 변화 (2008-2022)', fontsize=16)

colors = ['#FF1493', '#1E90FF']
categories = ['매우 안전', '비교적 안전', '보통', '비교적 안전하지 않음', '매우 안전하지 않음']
linestyles = ['solid', 'dashed']

for i, category in enumerate(categories):
    row = i // 2
    col = i % 2
    
    for j, gender in enumerate(genders):
        gender_data = df_result[df_result['성별'] == gender]
        axs[row, col].plot(gender_data['연도'], gender_data[category], label=gender, color=colors[j], marker='o', linestyle=linestyles[j])
    
    axs[row, col].set_title(category)
    axs[row, col].set_xlabel('연도')
    axs[row, col].set_ylabel('비율 (%)')
    axs[row, col].legend(title='성별', loc='best')
    axs[row, col].grid(True)

# 마지막 빈 서브플롯 제거
fig.delaxes(axs[2, 1])

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import font_manager, rc

# 성별 리스트
genders = ['남자', '여자']

# 연도별 데이터 추출 및 재구성
years = ['2008', '2010', '2012', '2014', '2016', '2018', '2020', '2022']
result_data = []

def safe_float(x):
    try:
        return float(x)
    except ValueError:
        return np.nan

for gender in genders:
    df_filtered = df_edu[(df_edu['특성별(1)'] == '성별') & (df_edu['특성별(2)'] == gender)]
    
    for year in years:
        row_data = [
            safe_float(df_filtered[year].values[0]),
            safe_float(df_filtered[f'{year}.1'].values[0]),
            safe_float(df_filtered[f'{year}.2'].values[0]),
            safe_float(df_filtered[f'{year}.3'].values[0]),
            safe_float(df_filtered[f'{year}.4'].values[0])
        ]
        result_data.append([gender, year] + row_data)

# 결과 데이터프레임 생성
df_result = pd.DataFrame(result_data, columns=['성별', '연도', '매우 안전', '비교적 안전', '보통', '비교적 안전하지 않음', '매우 안전하지 않음'])

# 성별로 평균과 표준편차 계산
mean_std_data = []

for gender in genders:
    gender_data = df_result[df_result['성별'] == gender][['매우 안전', '비교적 안전', '보통', '비교적 안전하지 않음', '매우 안전하지 않음']]
    means = gender_data.mean()
    stds = gender_data.std()
    mean_std_data.append([gender] + list(means) + list(stds))

# 결과 데이터프레임 생성 (평균과 표준편차)
mean_std_columns = ['성별'] + [f'{col}_mean' for col in ['매우 안전', '비교적 안전', '보통', '비교적 안전하지 않음', '매우 안전하지 않음']] + \
                   [f'{col}_std' for col in ['매우 안전', '비교적 안전', '보통', '비교적 안전하지 않음', '매우 안전하지 않음']]
df_mean_std = pd.DataFrame(mean_std_data, columns=mean_std_columns)

# 막대 그래프 생성 (평균과 표준편차)
categories = ['매우 안전', '비교적 안전', '보통', '비교적 안전하지 않음', '매우 안전하지 않음']
fig, axs = plt.subplots(3, 2, figsize=(20, 15))
fig.suptitle('2008년부터 2022년까지 성별 국내 자연재해 인식의 평균과 표준편차')

for i, category in enumerate(categories):
    row = i // 2
    col = i % 2
    
    means_col = f'{category}_mean'
    stds_col = f'{category}_std'
    
    x_pos = np.arange(len(genders))
    
    # 막대 그래프 그리기
    axs[row, col].bar(x_pos, df_mean_std[means_col], yerr=df_mean_std[stds_col], capsize=5, alpha=0.7, color='skyblue')
    
    # 그래프 제목 및 라벨 설정
    axs[row, col].set_title(category)
    axs[row, col].set_xticks(x_pos)
    axs[row, col].set_xticklabels(genders)
    axs[row, col].set_ylabel('비율 (%)')

# 마지막 빈 서브플롯 제거
fig.delaxes(axs[2, 1])

plt.tight_layout()
plt.show()

# %% [markdown]
# 일반적으로 비슷한 추세를 보이지만, 상대적으로 남성이 여성보다 안전하다는 견해를 가지고 있습니다.

# %% [markdown]
# ## 가구소득별

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
import numpy as np


# 가구소득 리스트
income_levels = ['100만원 미만', '100∼200만원 미만', '200∼300만원 미만', '300∼400만원 미만', 
                 '400∼500만원 미만', '500∼600만원 미만', '600만원 이상']

# 연도별 데이터 추출 및 재구성
years = ['2008', '2010', '2012', '2014', '2016', '2018', '2020', '2022']
result_data = []

def safe_float(x):
    try:
        return float(x)
    except ValueError:
        return np.nan

for income in income_levels:
    df_filtered = df_edu[(df_edu['특성별(1)'] == '가구소득') & (df_edu['특성별(2)'] == income)]
    
    for year in years:
        row_data = [
            safe_float(df_filtered[year].values[0]),
            safe_float(df_filtered[f'{year}.1'].values[0]),
            safe_float(df_filtered[f'{year}.2'].values[0]),
            safe_float(df_filtered[f'{year}.3'].values[0]),
            safe_float(df_filtered[f'{year}.4'].values[0])
        ]
        result_data.append([income, year] + row_data)

# 결과 데이터프레임 생성
df_result = pd.DataFrame(result_data, columns=['가구소득', '연도', '매우 안전', '비교적 안전', '보통', '비교적 안전하지 않음', '매우 안전하지 않음'])

# 선 그래프 생성
fig, axs = plt.subplots(3, 2, figsize=(20, 15))
fig.suptitle('가구소득별 국내 자연재해 안전도 인식 변화 (2008-2022)', fontsize=16)

colors = plt.cm.rainbow(np.linspace(0, 1, len(income_levels)))
categories = ['매우 안전', '비교적 안전', '보통', '비교적 안전하지 않음', '매우 안전하지 않음']
linestyles = ['-', '--', '-.', ':', '-', '--', '-.']

for i, category in enumerate(categories):
    row = i // 2
    col = i % 2
    
    for j, income in enumerate(income_levels):
        income_data = df_result[df_result['가구소득'] == income]
        axs[row, col].plot(income_data['연도'], income_data[category], label=income, color=colors[j], marker='o', linestyle=linestyles[j])
    
    axs[row, col].set_title(category)
    axs[row, col].set_xlabel('연도')
    axs[row, col].set_ylabel('비율 (%)')
    axs[row, col].legend(title='가구소득', loc='center left', bbox_to_anchor=(1, 0.5))
    axs[row, col].grid(True)

# 마지막 빈 서브플롯 제거
fig.delaxes(axs[2, 1])

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import font_manager, rc


# 가구소득 리스트
income_levels = ['100만원 미만', '100∼200만원 미만', '200∼300만원 미만', '300∼400만원 미만', 
                 '400∼500만원 미만', '500∼600만원 미만', '600만원 이상']

# 연도별 데이터 추출 및 재구성
years = ['2008', '2010', '2012', '2014', '2016', '2018', '2020', '2022']
result_data = []

def safe_float(x):
    try:
        return float(x)
    except ValueError:
        return np.nan

for income in income_levels:
    df_filtered = df_edu[(df_edu['특성별(1)'] == '가구소득') & (df_edu['특성별(2)'] == income)]
    
    for year in years:
        row_data = [
            safe_float(df_filtered[year].values[0]),
            safe_float(df_filtered[f'{year}.1'].values[0]),
            safe_float(df_filtered[f'{year}.2'].values[0]),
            safe_float(df_filtered[f'{year}.3'].values[0]),
            safe_float(df_filtered[f'{year}.4'].values[0])
        ]
        result_data.append([income, year] + row_data)

# 결과 데이터프레임 생성
df_result = pd.DataFrame(result_data, columns=['가구소득', '연도', '매우 안전', '비교적 안전', '보통', '비교적 안전하지 않음', '매우 안전하지 않음'])

# 가구소득별로 평균과 표준편차 계산
mean_std_data = []

for income in income_levels:
    income_data = df_result[df_result['가구소득'] == income][['매우 안전', '비교적 안전', '보통', '비교적 안전하지 않음', '매우 안전하지 않음']]
    means = income_data.mean()
    stds = income_data.std()
    mean_std_data.append([income] + list(means) + list(stds))

# 결과 데이터프레임 생성 (평균과 표준편차)
mean_std_columns = ['가구소득'] + [f'{col}_mean' for col in ['매우 안전', '비교적 안전', '보통', '비교적 안전하지 않음', '매우 안전하지 않음']] + \
                   [f'{col}_std' for col in ['매우 안전', '비교적 안전', '보통', '비교적 안전하지 않음', '매우 안전하지 않음']]
df_mean_std = pd.DataFrame(mean_std_data, columns=mean_std_columns)

# 막대 그래프 생성 (평균과 표준편차)
categories = ['매우 안전', '비교적 안전', '보통', '비교적 안전하지 않음', '매우 안전하지 않음']
fig, axs = plt.subplots(3, 2, figsize=(20, 15))
fig.suptitle('2008년부터 2022년까지 가구소득별 국내 자연재해 인식의 평균과 표준편차')

for i, category in enumerate(categories):
    row = i // 2
    col = i % 2
    
    means_col = f'{category}_mean'
    stds_col = f'{category}_std'
    
    x_pos = np.arange(len(income_levels))
    
    # 막대 그래프 그리기
    axs[row, col].bar(x_pos, df_mean_std[means_col], yerr=df_mean_std[stds_col], capsize=5, alpha=0.7, color='skyblue')
    
    # 그래프 제목 및 라벨 설정
    axs[row, col].set_title(category)
    axs[row, col].set_xticks(x_pos)
    axs[row, col].set_xticklabels(income_levels)
    axs[row, col].set_ylabel('비율 (%)')

# 마지막 빈 서브플롯 제거
fig.delaxes(axs[2, 1])

plt.tight_layout()
plt.show()

# %% [markdown]
# #### 고소득일수록 안전에 긍정적인 견해를 가지고 있으나 세월호 참사 당시에는 매우 안전하지 않음에 응답한 경우가 가장 많았습니다.

# %% [markdown]
# ## 산업별

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
import numpy as np


# 산업 리스트
industries = ['농림어업', '광공업', '사회간접자본․기타서비스업']

# 연도별 데이터 추출 및 재구성
years = ['2008', '2010', '2012', '2014', '2016', '2018', '2020', '2022']
result_data = []

def safe_float(x):
    try:
        return float(x)
    except ValueError:
        return np.nan

for industry in industries:
    df_filtered = df_edu[(df_edu['특성별(1)'] == '산업') & (df_edu['특성별(2)'] == industry)]
    
    for year in years:
        row_data = [
            safe_float(df_filtered[year].values[0]),
            safe_float(df_filtered[f'{year}.1'].values[0]),
            safe_float(df_filtered[f'{year}.2'].values[0]),
            safe_float(df_filtered[f'{year}.3'].values[0]),
            safe_float(df_filtered[f'{year}.4'].values[0])
        ]
        result_data.append([industry, year] + row_data)

# 결과 데이터프레임 생성
df_result = pd.DataFrame(result_data, columns=['산업', '연도', '매우 안전', '비교적 안전', '보통', '비교적 안전하지 않음', '매우 안전하지 않음'])

# 선 그래프 생성
fig, axs = plt.subplots(3, 2, figsize=(20, 15))
fig.suptitle('산업별 국내 자연재해 안전도 인식 변화 (2008-2022)', fontsize=16)

colors = ['#FF1493', '#1E90FF', '#32CD32']
categories = ['매우 안전', '비교적 안전', '보통', '비교적 안전하지 않음', '매우 안전하지 않음']
linestyles = ['-', '--', '-.']

for i, category in enumerate(categories):
    row = i // 2
    col = i % 2
    
    for j, industry in enumerate(industries):
        industry_data = df_result[df_result['산업'] == industry]
        axs[row, col].plot(industry_data['연도'], industry_data[category], label=industry, color=colors[j], marker='o', linestyle=linestyles[j])
    
    axs[row, col].set_title(category)
    axs[row, col].set_xlabel('연도')
    axs[row, col].set_ylabel('비율 (%)')
    axs[row, col].legend(title='산업', loc='best')
    axs[row, col].grid(True)

# 마지막 빈 서브플롯 제거
fig.delaxes(axs[2, 1])

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import font_manager, rc


# 산업 리스트
industries = ['농림어업', '광공업', '사회간접자본․기타서비스업']

# 연도별 데이터 추출 및 재구성
years = ['2008', '2010', '2012', '2014', '2016', '2018', '2020', '2022']
result_data = []

def safe_float(x):
    try:
        return float(x)
    except ValueError:
        return np.nan

for industry in industries:
    df_filtered = df_edu[(df_edu['특성별(1)'] == '산업') & (df_edu['특성별(2)'] == industry)]
    
    for year in years:
        row_data = [
            safe_float(df_filtered[year].values[0]),
            safe_float(df_filtered[f'{year}.1'].values[0]),
            safe_float(df_filtered[f'{year}.2'].values[0]),
            safe_float(df_filtered[f'{year}.3'].values[0]),
            safe_float(df_filtered[f'{year}.4'].values[0])
        ]
        result_data.append([industry, year] + row_data)

# 결과 데이터프레임 생성
df_result = pd.DataFrame(result_data, columns=['산업', '연도', '매우 안전', '비교적 안전', '보통', '비교적 안전하지 않음', '매우 안전하지 않음'])

# 산업별로 평균과 표준편차 계산
mean_std_data = []

for industry in industries:
    industry_data = df_result[df_result['산업'] == industry][['매우 안전', '비교적 안전', '보통', '비교적 안전하지 않음', '매우 안전하지 않음']]
    means = industry_data.mean()
    stds = industry_data.std()
    mean_std_data.append([industry] + list(means) + list(stds))

# 결과 데이터프레임 생성 (평균과 표준편차)
mean_std_columns = ['산업'] + [f'{col}_mean' for col in ['매우 안전', '비교적 안전', '보통', '비교적 안전하지 않음', '매우 안전하지 않음']] + \
                   [f'{col}_std' for col in ['매우 안전', '비교적 안전', '보통', '비교적 안전하지 않음', '매우 안전하지 않음']]
df_mean_std = pd.DataFrame(mean_std_data, columns=mean_std_columns)

# 막대 그래프 생성 (평균과 표준편차)
categories = ['매우 안전', '비교적 안전', '보통', '비교적 안전하지 않음', '매우 안전하지 않음']
fig, axs = plt.subplots(3, 2, figsize=(20, 15))
fig.suptitle('2008년부터 2022년까지 산업별 국내 자연재해 인식의 평균과 표준편차')

for i, category in enumerate(categories):
    row = i // 2
    col = i % 2
    
    means_col = f'{category}_mean'
    stds_col = f'{category}_std'
    
    x_pos = np.arange(len(industries))
    
    # 막대 그래프 그리기
    axs[row, col].bar(x_pos, df_mean_std[means_col], yerr=df_mean_std[stds_col], capsize=5, alpha=0.7, color='skyblue')
    
    # 그래프 제목 및 라벨 설정
    axs[row, col].set_title(category)
    axs[row, col].set_xticks(x_pos)
    axs[row, col].set_xticklabels(industries)
    axs[row, col].set_ylabel('비율 (%)')

# 마지막 빈 서브플롯 제거
fig.delaxes(axs[2][1])

plt.tight_layout()
plt.show()

# %% [markdown]
# #### 자연에 밀접한 관련을 가지는 농업종사자들이 안전에 부정적인 견해를 가지고 있습니다.

# %% [markdown]
# ## 직업별

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
import numpy as np


# 직업 리스트 (공백 문자 처리)
occupations = ['전문관리', '사  무', '서비스판매', '농어업', '기능노무']

# 연도별 데이터 추출 및 재구성
years = ['2008', '2010', '2012', '2014', '2016', '2018', '2020', '2022']
result_data = []

def safe_float(x):
    try:
        return float(x)
    except (ValueError, TypeError):
        return np.nan

for occupation in occupations:
    df_filtered = df_edu[(df_edu['특성별(1)'] == '직업') & (df_edu['특성별(2)'].str.strip() == occupation.strip())]
    
    for year in years:
        if not df_filtered.empty:
            row_data = [
                safe_float(df_filtered[year].values[0]),
                safe_float(df_filtered[f'{year}.1'].values[0]),
                safe_float(df_filtered[f'{year}.2'].values[0]),
                safe_float(df_filtered[f'{year}.3'].values[0]),
                safe_float(df_filtered[f'{year}.4'].values[0])
            ]
        else:
            row_data = [np.nan] * 5
        result_data.append([occupation, year] + row_data)

# 결과 데이터프레임 생성
df_result = pd.DataFrame(result_data, columns=['직업', '연도', '매우 안전', '비교적 안전', '보통', '비교적 안전하지 않음', '매우 안전하지 않음'])

# 선 그래프 생성
fig, axs = plt.subplots(3, 2, figsize=(20, 15))
fig.suptitle('직업별 국내 자연재해 안전도 인식 변화 (2008-2022)', fontsize=16)

colors = ['#FF1493', '#1E90FF', '#32CD32', '#FFA500', '#8B008B']
categories = ['매우 안전', '비교적 안전', '보통', '비교적 안전하지 않음', '매우 안전하지 않음']
linestyles = ['-', '--', '-.', ':', '-']

for i, category in enumerate(categories):
    row = i // 2
    col = i % 2
    
    for j, occupation in enumerate(occupations):
        occupation_data = df_result[df_result['직업'] == occupation]
        axs[row, col].plot(occupation_data['연도'], occupation_data[category], label=occupation, color=colors[j], marker='o', linestyle=linestyles[j])
    
    axs[row, col].set_title(category)
    axs[row, col].set_xlabel('연도')
    axs[row, col].set_ylabel('비율 (%)')
    axs[row, col].legend(title='직업', loc='best')
    axs[row, col].grid(True)

# 마지막 빈 서브플롯 제거
fig.delaxes(axs[2, 1])

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
import numpy as np


# 직업 리스트 (공백 문자 처리)
occupations = ['전문관리', '사  무', '서비스판매', '농어업', '기능노무']

# 연도별 데이터 추출 및 재구성
years = ['2008', '2010', '2012', '2014', '2016', '2018', '2020', '2022']
result_data = []

def safe_float(x):
    try:
        return float(x)
    except (ValueError, TypeError):
        return np.nan

for occupation in occupations:
    df_filtered = df_edu[(df_edu['특성별(1)'] == '직업') & (df_edu['특성별(2)'].str.strip() == occupation.strip())]
    
    for year in years:
        if not df_filtered.empty:
            row_data = [
                safe_float(df_filtered[year].values[0]),
                safe_float(df_filtered[f'{year}.1'].values[0]),
                safe_float(df_filtered[f'{year}.2'].values[0]),
                safe_float(df_filtered[f'{year}.3'].values[0]),
                safe_float(df_filtered[f'{year}.4'].values[0])
            ]
        else:
            row_data = [np.nan] * 5
        result_data.append([occupation, year] + row_data)

# 결과 데이터프레임 생성
df_result = pd.DataFrame(result_data, columns=['직업', '연도', '매우 안전', '비교적 안전', '보통', '비교적 안전하지 않음', '매우 안전하지 않음'])

# 선 그래프 생성
fig, axs = plt.subplots(3, 2, figsize=(20, 15))
fig.suptitle('직업별 국내 자연재해 안전도 인식 변화 (2008-2022)', fontsize=16)

colors = ['#FF1493', '#1E90FF', '#32CD32', '#FFA500', '#8B008B']
categories = ['매우 안전', '비교적 안전', '보통', '비교적 안전하지 않음', '매우 안전하지 않음']
linestyles = ['-', '--', '-.', ':', '-']

for i, category in enumerate(categories):
    row = i // 2
    col = i % 2
    
    for j, occupation in enumerate(occupations):
        occupation_data = df_result[df_result['직업'] == occupation]
        axs[row, col].plot(occupation_data['연도'], occupation_data[category], label=occupation, color=colors[j], marker='o', linestyle=linestyles[j])
    
    axs[row, col].set_title(category)
    axs[row, col].set_xlabel('연도')
    axs[row, col].set_ylabel('비율 (%)')
    axs[row, col].legend(title='직업', loc='best')
    axs[row, col].grid(True)

# 마지막 빈 서브플롯 제거
fig.delaxes(axs[2, 1])

plt.tight_layout()
plt.show()

# %% [markdown]
# #### 직업도 마찬가지로 농어업에 종사하고 있는 사람들이 안전에 대해 부정적인 견해를 가지고 있다는 점을 알 수 있습니다.
